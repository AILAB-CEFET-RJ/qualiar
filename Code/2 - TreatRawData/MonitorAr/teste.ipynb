# %%
import pandas as pd
from io import BytesIO
import certifi
import requests

# %%
url_internacoes = "https://raw.githubusercontent.com/AILAB-CEFET-RJ/qualiar/refs/heads/Refactoring-And-Documentation/Data/RawData/MonitorAr/dados_unidades_moveis.parquet"

response = requests.get(url_internacoes, verify=certifi.where(), timeout=60)
response.raise_for_status()

df_internacoes = pd.read_parquet(BytesIO(response.content))

# %%
df_internacoes
# Out:
#     OBJECTID    Name  Data_inicio  Data_fim        Lat       Long  \
# 0          1    UMVC          NaN       NaN -22.853070 -43.311864
# 1          2    UMCE          NaN       NaN -22.905003 -43.177788
# 2          3    UMGV          NaN       NaN -22.978589 -43.231621
# 3          4    UMGM          NaN       NaN -22.871400 -43.459422
# 4          5    UMCP          NaN       NaN -22.976488 -43.193708
# 5          6    UMMD          NaN       NaN -22.865555 -43.343363
# 6          7    UMDC          NaN       NaN -22.872846 -43.273213
# 7          8    UMMA          NaN       NaN -22.910299 -43.235205
# 8          9    UMPM          NaN       NaN -22.899568 -43.176431
# 9         10    UMPR          NaN       NaN -22.894659 -43.198834
# 10        11    UMCJ          NaN       NaN -22.876072 -43.211703
# 11        12    UMCA          NaN       NaN -22.875845 -43.222494
# 12        13  UMCAJU          NaN       NaN -22.879856 -43.227339
# ...
